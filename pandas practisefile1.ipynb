# %% [markdown]
# pandas practise

# %%
import pandas as pd 
df = pd.DataFrame([{"firstname":"Padmavathi","lastname" :"Sonnaila"},
                   {"firstname":"Santhosh","lastname":"Sonnaila"},
                   {"firstname":"Pramod","lastname":"Palakala"},
                   {"firstname":" ","lastname":"kumari"}])
df
# Out:
#     firstname  lastname
# 0  Padmavathi  Sonnaila
# 1    Santhosh  Sonnaila
# 2      Pramod  Palakala
# 3                kumari

# %%
import pandas as pd
restaurants =pd.read_csv("D:\program.csv")

# %%
restaurants
# Out:
#            CAMIS                        DBA       BORO BUILDING  \
# 0       30075445      MORRIS PARK BAKE SHOP      BRONX     1007
# 1       30075445      MORRIS PARK BAKE SHOP      BRONX     1007
# 2       30075445      MORRIS PARK BAKE SHOP      BRONX     1007
# 3       30075445      MORRIS PARK BAKE SHOP      BRONX     1007
# 4       30075445      MORRIS PARK BAKE SHOP      BRONX     1007
# 5       30075445      MORRIS PARK BAKE SHOP      BRONX     1007
# 6       30075445      MORRIS PARK BAKE SHOP      BRONX     1007
# 7       30075445      MORRIS PARK BAKE SHOP      BRONX     1007
# 8       30075445      MORRIS PARK BAKE SHOP      BRONX     1007
# 9       30112340                    WENDY'S   BROOKLYN      469
# 10      30112340                    WENDY'S   BROOKLYN      469
# 11      30112340                    WENDY'S   BROOKLYN      469
# 12      30112340                    WENDY'S   BROOKLYN      469
# 13      30112340                    WENDY'S   BROOKLYN      469
# ...

# %%
list(restaurants)
# Out:
# ['CAMIS',
#  'DBA',
#  'BORO',
#  'BUILDING',
#  'STREET',
#  'ZIPCODE',
#  'PHONE',
#  'CUISINE DESCRIPTION',
#  'INSPECTION DATE',
#  'ACTION',
#  'VIOLATION CODE',
#  'VIOLATION DESCRIPTION',
#  'CRITICAL FLAG',
#  'SCORE',
#  'GRADE',
#  'GRADE DATE',
#  'RECORD DATE',
#  'INSPECTION TYPE']

# %%
restaurants.head()
# Out:
#       CAMIS                    DBA   BORO BUILDING           STREET  ZIPCODE  \
# 0  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE  10462.0
# 1  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE  10462.0
# 2  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE  10462.0
# 3  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE  10462.0
# 4  30075445  MORRIS PARK BAKE SHOP  BRONX     1007  MORRIS PARK AVE  10462.0
#
#         PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  7188924968              Bakery      05/16/2019
# 1  7188924968              Bakery      05/16/2019
# 2  7188924968              Bakery      05/16/2019
# 3  7188924968              Bakery      05/16/2019
# 4  7188924968              Bakery      05/16/2019
#
#                                             ACTION VIOLATION CODE  \
# 0  Violations were cited in the following area(s).            04L
# ...

# %%
restaurants.tail()
# Out:
#            CAMIS                     DBA       BORO BUILDING  \
# 382816  50093057  EL ATORADERO BROOOKLYN   BROOKLYN      706
# 382817  50093064                     NaN  MANHATTAN      620
# 382818  50093065                     NaN  MANHATTAN       39
# 382819  50093068        CONRADO BALDERAS      BRONX     1086
# 382820  50093071             SAVORY THAI   BROOKLYN      378
#
#                   STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 382816    WASHINGTON AVE  11238.0  3476632951               Other
# 382817         W 42ND ST  10036.0  6464564673               Other
# 382818          ESSEX ST  10002.0  2125181363               Other
# 382819     SOUTHERN BLVD  10459.0  6465716314               Other
# 382820  METROPOLITAN AVE  11211.0  3472552512               Other
#
#        INSPECTION DATE ACTION VIOLATION CODE VIOLATION DESCRIPTION  \
# 382816      01/01/1900    NaN            NaN                   NaN
# ...

# %%
restaurants.dtypes
# Out:
# CAMIS                      int64
# DBA                       object
# BORO                      object
# BUILDING                  object
# STREET                    object
# ZIPCODE                  float64
# PHONE                     object
# CUISINE DESCRIPTION       object
# INSPECTION DATE           object
# ACTION                    object
# VIOLATION CODE            object
# VIOLATION DESCRIPTION     object
# CRITICAL FLAG             object
# SCORE                    float64
# GRADE                     object
# GRADE DATE                object
# RECORD DATE               object
# INSPECTION TYPE           object
# dtype: object

# %%
restaurants.describe()
# Out:
#               CAMIS        ZIPCODE          SCORE
# count  3.828210e+05  377281.000000  364865.000000
# mean   4.579923e+07   10675.958426      19.822841
# std    4.424595e+06     596.472477      14.232408
# min    3.007544e+07   10000.000000      -1.000000
# 25%    4.135364e+07   10022.000000      11.000000
# 50%    5.000158e+07   10468.000000      15.000000
# 75%    5.004783e+07   11229.000000      25.000000
# max    5.009307e+07   12345.000000     166.000000

# %%
restaurants.SCORE.describe()
# Out:
# count    364865.000000
# mean         19.822841
# std          14.232408
# min          -1.000000
# 25%          11.000000
# 50%          15.000000
# 75%          25.000000
# max         166.000000
# Name: SCORE, dtype: float64

# %%
restaurants.SCORE
# Out:
# 0         18.0
# 1         18.0
# 2         18.0
# 3         18.0
# 4         18.0
# 5          5.0
# 6          5.0
# 7          7.0
# 8          7.0
# 9         13.0
# 10        13.0
# 11        13.0
# 12        12.0
# 13        12.0
# 14        12.0
# 15        10.0
# 16        10.0
# 17         7.0
# 18        11.0
# 19        11.0
# 20        48.0
# 21        48.0
# 22        48.0
# 23        48.0
# 24        48.0
# 25        13.0
# 26        13.0
# 27        13.0
# 28        13.0
# 29         NaN
#           ...
# 382791     NaN
# 382792     NaN
# 382793     NaN
# 382794     NaN
# 382795     NaN
# 382796     NaN
# 382797     NaN
# 382798     NaN
# 382799     NaN
# 382800     NaN
# 382801     NaN
# 382802     NaN
# 382803     NaN
# 382804     NaN
# 382805     NaN
# 382806     NaN
# 382807     NaN
# 382808     NaN
# 382809     NaN
# 382810     NaN
# 382811     NaN
# 382812     NaN
# 382813     NaN
# 382814     NaN
# 382815     NaN
# 382816     NaN
# 382817     NaN
# ...

# %%
restaurants["SCORE1"] = pd.to_numeric(restaurants["SCORE"])
restaurants.dtypes
# Out:
# CAMIS                      int64
# DBA                       object
# BORO                      object
# BUILDING                  object
# STREET                    object
# ZIPCODE                  float64
# PHONE                     object
# CUISINE DESCRIPTION       object
# INSPECTION DATE           object
# ACTION                    object
# VIOLATION CODE            object
# VIOLATION DESCRIPTION     object
# CRITICAL FLAG             object
# SCORE                    float64
# GRADE                     object
# GRADE DATE                object
# RECORD DATE               object
# INSPECTION TYPE           object
# SCORE1                   float64
# dtype: object

# %%
restaurants.SCORE.describe()
# Out:
# count    364865.000000
# mean         19.822841
# std          14.232408
# min          -1.000000
# 25%          11.000000
# 50%          15.000000
# 75%          25.000000
# max         166.000000
# Name: SCORE, dtype: float64
