# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_excel(r"D:\filename\ora_ju.xlsx")

# %%
df
# Out:
#        yr  Wk  own_brand_tv_grp  basepricepergal  top3pctbvap   temp  \
# 0    2006   1              73.0             4.95         0.29  34.67
# 1    2006   2              45.0             5.02         0.37  33.66
# 2    2006   3              40.0             5.07         0.38  30.73
# 3    2006   4              52.0             5.09         0.41  34.68
# 4    2006   5              45.0             5.12         0.39  31.22
# 5    2006   6              55.0             5.15         0.35  23.96
# 6    2006   7              42.0             5.18         0.36  19.84
# 7    2006   8              51.0             5.17         0.39  25.92
# 8    2006   9              42.0             5.17         0.38  32.49
# 9    2006  10              51.0             5.17         0.42  40.38
# 10   2006  11               1.0             5.18         0.40  32.59
# 11   2006  12               0.0             5.18         0.36  32.04
# 12   2006  13              59.0             5.18         0.34  45.39
# ...

# %%
df.head()
# Out:
#      yr  Wk  own_brand_tv_grp  basepricepergal  top3pctbvap   temp  gasprice  \
# 0  2006   1              73.0             4.95         0.29  34.67     233.2
# 1  2006   2              45.0             5.02         0.37  33.66     226.3
# 2  2006   3              40.0             5.07         0.38  30.73     228.2
# 3  2006   4              52.0             5.09         0.41  34.68     231.4
# 4  2006   5              45.0             5.12         0.39  31.22     228.0
#
#    brand1tv  brand2tv  xmaswkind  easterwkind  nywkind    ojvol
# 0      0.11      0.19          0            0        1  3753938
# 1      0.15      0.15          0            0        0  3530670
# 2      0.19      0.34          0            0        0  3575088
# 3      0.15      0.30          0            0        0  3453849
# 4      0.20      0.43          0            0        0  3432755

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 13 columns):
# yr                  196 non-null int64
# Wk                  196 non-null int64
# own_brand_tv_grp    196 non-null float64
# basepricepergal     196 non-null float64
# top3pctbvap         196 non-null float64
# temp                196 non-null float64
# gasprice            196 non-null float64
# brand1tv            196 non-null float64
# brand2tv            196 non-null float64
# xmaswkind           196 non-null int64
# easterwkind         196 non-null int64
# nywkind             196 non-null int64
# ojvol               196 non-null int64
# dtypes: float64(7), int64(6)
# memory usage: 20.0 KB

# %%
df.describe()
# Out:
#                 yr          Wk  own_brand_tv_grp  basepricepergal  \
# count   196.000000  196.000000        196.000000       196.000000
# mean   2007.408163   25.275510         31.370396         5.960255
# std       1.089217   14.608589         25.924055         0.412647
# min    2006.000000    1.000000          0.000000         4.950000
# 25%    2006.000000   13.000000          0.675000         5.590000
# 50%    2007.000000   25.000000         42.000000         6.170000
# 75%    2008.000000   37.000000         52.075000         6.272500
# max    2009.000000   52.000000         84.000000         6.350000
#
#        top3pctbvap        temp    gasprice    brand1tv    brand2tv  \
# count   196.000000  196.000000  196.000000  196.000000  196.000000
# mean      0.321276   48.722041  271.108163    0.167959    0.155357
# std       0.044050   18.882743   58.531700    0.055126    0.180902
# min       0.210000    5.340000  156.700000    0.050000    0.000000
# ...

# %%
df.shape
# Out:
# (196, 13)

# %%
df.keys()
# Out:
# Index(['yr', 'Wk', 'own_brand_tv_grp', 'basepricepergal', 'top3pctbvap',
#        'temp', 'gasprice', 'brand1tv', 'brand2tv', 'xmaswkind', 'easterwkind',
#        'nywkind', 'ojvol'],
#       dtype='object')

# %%
print(df.ojvol)
# Out:
# 0      3753938
# 1      3530670
# 2      3575088
# 3      3453849
# 4      3432755
# 5      3477089
# 6      3495436
# 7      3441342
# 8      3409081
# 9      3342894
# 10     3318522
# 11     3287168
# 12     3070238
# 13     3277939
# 14     3408545
# 15     3024399
# 16     2934731
# 17     3036521
# 18     3078160
# 19     2951452
# 20     2857231
# 21     2994472
# 22     2899591
# 23     2912457
# 24     2823625
# 25     2791134
# 26     2826516
# 27     2879820
# 28     2823409
# 29     2777428
#         ...
# 166    2809375
# 167    2736887
# 168    2666860
# 169    2819272
# 170    3044494
# 171    2521253
# 172    2633706
# 173    2607233
# 174    2756362
# 175    2609904
# 176    2460687
# 177    2378026
# 178    2666728
# 179    2565470
# 180    2472588
# 181    2430251
# 182    2523299
# 183    2430957
# 184    2378333
# 185    2302893
# 186    2367359
# 187    2565587
# 188    2561180
# 189    2524423
# 190    2353574
# 191    2615927
# 192    2698007
# 193    2589453
# ...

# %%
df.hist(bins=50, figsize=(25, 20))
plt.show()

# %% [markdown]
# # jointplot

# %%
sns.jointplot(df['ojvol'], df['gasprice'])

# %%
sns.jointplot(df['ojvol'], df['own_brand_tv_grp'])

# %%
sns.jointplot(df['ojvol'], df['gasprice'])

# %% [markdown]
# # pairplot

# %%
sns.pairplot(df)

# %% [markdown]
# # linear model plot

# %%
sns.lmplot('ojvol', 'gasprice', df)

# %%
sns.lmplot('ojvol', 'own_brand_tv_grp', df)

# %%
df.drop_duplicates(keep='first', inplace=True)
